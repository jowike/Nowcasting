# %%
import pandas as pd
from eval_plots import plot_corr_matrix
pd.set_option('display.max_columns', 30)

# %%
X_train = pd.read_csv("./data/2017-01-01/X_train.csv", index_col=0)
y_train = pd.read_csv("./data/2017-01-01/y_train.csv", index_col=0)
Z_df = pd.read_csv("./data/2017-01-01/Z_df.csv", index_col=0)

# %%
data = Z_df
data_transf = pd.merge(X_train, y_train, left_index=True, right_index=True)

# %%
plot_corr_matrix(data_transf.corr())
plot_corr_matrix(data.corr())
