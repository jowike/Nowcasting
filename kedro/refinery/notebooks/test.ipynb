# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/02_intermediate/preprocessed_vintages.parquet")

# %%
df.VariableCode.unique()
# Out:
# array(['GDPC1', 'BUSINV', 'GACDISA066MSFRBNY', 'DSPIC96', 'PCEPI',
#        'PCEPILFE', 'RSAFS', 'TTLCONS', 'CPIAUCSL', 'CPILFESL', 'UNRATE',
#        'PAYEMS', 'INDPRO', 'TCU', 'JTSJOL', 'DGORDER',
#        'GACDFSA066MSFRBPHI', 'HOUST', 'PERMIT', 'PCEC96', 'IR', 'IQ',
#        'BOPTIMP', 'BOPTEXP'], dtype=object)

# %%
# align_ragged_edges
